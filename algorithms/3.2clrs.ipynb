# %% [markdown]
# # **Introduction to Algorithms (CLRS)**
# #### My notes, code, and more
# # Chapter 3: Data Structures - **Hash Tables**

# %% [markdown]
# Background:
#
# Many applications require only dicitonary operations such as, INSERT, SEARCH, and DELETE. For example, a compiler that translates a programming language maintains a symbol table.
#
# A Hash Table is an effective data structure for these needs/implementing dictionaries.

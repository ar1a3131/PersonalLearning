# %% [markdown]
# # **Designing Data-Intensive Applications - notes**

# %% [markdown]
# ## Chapter 2 Highlights
#
# Definitions:
# - Data Model: a visual blueprint that organizes how data is structured, stored, and connected in a system or database

# %% [markdown]
# ## ***Chapter 2: other notes for myself***
